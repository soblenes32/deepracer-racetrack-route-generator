# %%
##

# %%
#Load racetrack and route modelling dependencies
# %run ./src/Racetrack.ipynb
# %run ./src/RacetrackCommandNodeSeries.ipynb
# %run ./src/SimpleGeneticAlgorithm.ipynb

# %%
#Load genetic algorithm default method implementations
# %run ./DeepRacerRouteGAMethods.ipynb

# %%
#How many routes in the pool
pool_size = 50
#How many generations to run
num_generations = 25
#How frequently to print status report
reporting_frequency = 5

# %%
#Initialize the racetrack
racetrack = Racetrack(waypointFilePath="./track-data/H_track.npy")
simpleGeneticAlgorthm = SimpleGeneticAlgorthm(pool_size=pool_size, verbosity=2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-c7922fff7d70> in <module>
#       1 #Initialize the racetrack
# ----> 2 racetrack = Racetrack(waypointFilePath="./track-data/H_track.npy")
#       3 simpleGeneticAlgorthm = SimpleGeneticAlgorthm(pool_size=pool_size, verbosity=2)
#
# <ipython-input-1-b338d3eee06b> in __init__(self, waypointFilePath)
#      24         #Remove duplicate waypoints
#      25         self.all_waypoints, aw_indices = np.unique(self.all_waypoints, axis=0, return_index=True)
# ---> 26         print('duplicate waypoints:',self.all_waypoints[aw_indices])
#      27         self.all_waypoints = self.all_waypoints[np.argsort(aw_indices)]
#      28         [self.waypoints_center, self.waypoints_inner, self.waypoints_outer] = np.split(self.all_waypoints, 3, axis=1)
#
# IndexError: index 124 is out of bounds for axis 0 with size 124

# %%
simpleGeneticAlgorthm.setInitializationMethod(initializationMethod)
simpleGeneticAlgorthm.setCrossoverMethod(crossoverMethod)
simpleGeneticAlgorthm.setMutationMethod(mutationMethod)
simpleGeneticAlgorthm.setFitnessMethod(fitness_method=fitnessMethod)
simpleGeneticAlgorthm.setReportingMethodAndFrequency(reporting_method=reportingMethod, reporting_frequency=reporting_frequency)

# %%
best_commandNodeSeries = simpleGeneticAlgorthm.evolve(num_generations=num_generations)
# Out:
# Initializing generations
# Fixing obstruction at command node: [0, 0.41267289941149743]
# last_cn_fix: -1
# Fixing obstruction at command node: [0, 0.4949364839248074]
# last_cn_fix: 0
# Unable to resolve route obstruction. This usually happens when there is a problem with the track data!
# Terminating...
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# E:\Dev\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
best_commandNodeSeries.plotBigTrackAndRoute(coordinate_labels=True)
