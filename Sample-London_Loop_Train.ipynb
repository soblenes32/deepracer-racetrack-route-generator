# %%
#Load racetrack and route modelling dependencies
# %run ./src/Racetrack.ipynb
# %run ./src/RacetrackCommandNodeSeries.ipynb
# %run ./src/SimpleGeneticAlgorithm.ipynb

# %%
#Load genetic algorithm default method implementations
# %run ./DeepRacerRouteGAMethods.ipynb

# %%
#How many routes in the pool
pool_size = 50
#How many generations to run
num_generations = 25
#How frequently to print status report
reporting_frequency = 5

# %%
#Initialize the racetrack
racetrack = Racetrack(waypointFilePath="./track-data/London_Loop_Train.npy")
simpleGeneticAlgorthm = SimpleGeneticAlgorthm(pool_size=pool_size)

# %%
simpleGeneticAlgorthm.setInitializationMethod(initializationMethod)
simpleGeneticAlgorthm.setCrossoverMethod(crossoverMethod)
simpleGeneticAlgorthm.setMutationMethod(mutationMethod)
simpleGeneticAlgorthm.setFitnessMethod(fitness_method=fitnessMethod)
simpleGeneticAlgorthm.setReportingMethodAndFrequency(reporting_method=reportingMethod, reporting_frequency=reporting_frequency)

# %%
best_commandNodeSeries = simpleGeneticAlgorthm.evolve(num_generations=num_generations)
# Out:
# Top 5 route fitness scores
# --------------------------
# 1 : 9.271602304979396
# 2 : 10.303004168375091
# 3 : 10.311146322270673
# 4 : 10.443720901171663
# 5 : 10.46203555646521
# 6 : 10.612165436464396
# evolving generation 1 of 25
# evolving generation 2 of 25
# evolving generation 3 of 25
# evolving generation 4 of 25
# evolving generation 5 of 25
# Top 5 route fitness scores
# --------------------------
# 1 : 8.370962289653967
# 2 : 8.414001014430145
# 3 : 8.558668138784471
# 4 : 9.031038103583207
# 5 : 9.031038103583207
# 6 : 9.087471950872244
# evolving generation 6 of 25
# evolving generation 7 of 25
# evolving generation 8 of 25
# evolving generation 9 of 25
# evolving generation 10 of 25
# Top 5 route fitness scores
# --------------------------
# 1 : 8.329153648585692
# 2 : 8.354583501147761
# 3 : 8.370962289653967
# 4 : 8.414001014430145
# 5 : 8.414001014430145
# 6 : 8.43916895333929
# evolving generation 11 of 25
# evolving generation 12 of 25
# evolving generation 13 of 25
# evolving generation 14 of 25
# evolving generation 15 of 25
# Top 5 route fitness scores
# --------------------------
# 1 : 8.042906564778992
# 2 : 8.042906564778992
# 3 : 8.066694125218255
# 4 : 8.066694125218255
# 5 : 8.066694125218255
# 6 : 8.107993390199324
# evolving generation 16 of 25
# evolving generation 17 of 25
# evolving generation 18 of 25
# evolving generation 19 of 25
# evolving generation 20 of 25
# Top 5 route fitness scores
# --------------------------
# 1 : 7.802168107687534
# 2 : 7.882450772914914
# 3 : 7.892866026717397
# 4 : 7.915198907777874
# 5 : 7.927097004147382
# 6 : 7.932737061449069
# evolving generation 21 of 25
# evolving generation 22 of 25
# evolving generation 23 of 25
# evolving generation 24 of 25
# evolving generation 25 of 25
# Final score: 7.526689152006955

# %%
best_commandNodeSeries.plotBigTrackAndRoute(coordinate_labels=True)
