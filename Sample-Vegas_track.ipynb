# %%
#Load racetrack and route modelling dependencies
# %run ./src/Racetrack.ipynb
# %run ./src/RacetrackCommandNodeSeries.ipynb
# %run ./src/SimpleGeneticAlgorithm.ipynb

# %%
#Load genetic algorithm default method implementations
# %run ./DeepRacerRouteGAMethods.ipynb

# %%
#How many routes in the pool
pool_size = 10
#How many generations to run
num_generations = 10
#How frequently to print status report
reporting_frequency = 1
#Set the frequency of command points (init_cp_frequency) to a lower number because this track has some very tight turns
#A low init_cp_frequency will take longer to converge to an optimum route
init_cp_frequency = 20
#Verbosity 0:silent, 1:basic, 2:unbearable
verbosity = 1

# %%
#Initialize the racetrack
racetrack = Racetrack(waypointFilePath="./track-data/Canada_Training.npy")
simpleGeneticAlgorthm = SimpleGeneticAlgorthm(pool_size=pool_size)

# %%
simpleGeneticAlgorthm.setInitializationMethod(initializationMethod)
simpleGeneticAlgorthm.setCrossoverMethod(crossoverMethod)
simpleGeneticAlgorthm.setMutationMethod(mutationMethod)
simpleGeneticAlgorthm.setFitnessMethod(fitness_method=fitnessMethod)
simpleGeneticAlgorthm.setReportingMethodAndFrequency(reporting_method=reportingMethod, reporting_frequency=reporting_frequency)

# %%
best_commandNodeSeries = simpleGeneticAlgorthm.evolve(num_generations=num_generations)
# Out:
# Initializing first generation pool of 10 ...
# Top 5 route fitness scores
# --------------------------
# 1 : 12.584625273015059
# 2 : 13.080120733761936
# 3 : 13.726740863137909
# 4 : 13.736693669447307
# 5 : 13.86412767608511
# 6 : 14.137937071776845
# evolving generation 1 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 12.42486842039922
# 2 : 12.584625273015059
# 3 : 13.10715387439085
# 4 : 13.563823037929504
# 5 : 13.587703632954412
# 6 : 13.902287976694264
# evolving generation 2 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 12.269375619252559
# 2 : 12.42486842039922
# 3 : 12.594157151079674
# 4 : 12.628215244854545
# 5 : 13.023052277034326
# 6 : 13.320247629433277
# evolving generation 3 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 12.059841923860967
# 2 : 12.269375619252559
# 3 : 13.070653463469396
# 4 : 13.25866240257736
# 5 : 13.337181196466801
# 6 : 13.763220697078834
# evolving generation 4 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 11.956203248056335
# 2 : 12.059841923860967
# 3 : 12.250173240137752
# 4 : 12.58119631312714
# 5 : 13.351225187720985
# 6 : 13.392651995283355
# evolving generation 5 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 11.275006701822292
# 2 : 11.956203248056335
# 3 : 12.098729067556746
# 4 : 12.731730471338874
# 5 : 12.851185352667741
# 6 : 13.789540606424918
# evolving generation 6 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 11.275006701822292
# 2 : 11.65908081369217
# 3 : 11.67110671236518
# 4 : 12.105329432060838
# 5 : 12.810206515362491
# 6 : 12.967316831283032
# evolving generation 7 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 11.275006701822292
# 2 : 11.809792227352897
# 3 : 11.90723216185048
# 4 : 12.127146966168644
# 5 : 12.647287687212552
# 6 : 13.006569446737782
# evolving generation 8 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 10.843672849004518
# 2 : 11.275006701822292
# 3 : 11.809792227352897
# 4 : 11.90723216185048
# 5 : 11.918899646568153
# 6 : 12.98080783101253
# evolving generation 9 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 10.843672849004518
# 2 : 10.917831640937882
# 3 : 11.380593974068443
# 4 : 11.860456702907925
# 5 : 12.017231662540459
# 6 : 12.798984991335344
# evolving generation 10 of 10
# Final score: 10.843672849004518

# %%
best_commandNodeSeries.plotBigTrackAndRoute(coordinate_labels=True)
