# %%
#Load racetrack and route modelling dependencies
# %run ./src/Racetrack.ipynb
# %run ./src/RacetrackCommandNodeSeries.ipynb
# %run ./src/SimpleGeneticAlgorithm.ipynb

# %%
#Load genetic algorithm default method implementations
# %run ./DeepRacerRouteGAMethods.ipynb

# %%
#How many routes in the pool
pool_size = 10
#How many generations to run
num_generations = 10
#How frequently to print status report
reporting_frequency = 1

# %%
#Initialize the racetrack
racetrack = Racetrack(waypointFilePath="./track-data/Oval_track.npy")
simpleGeneticAlgorthm = SimpleGeneticAlgorthm(pool_size=pool_size)

# %%
simpleGeneticAlgorthm.setInitializationMethod(initializationMethod)
simpleGeneticAlgorthm.setCrossoverMethod(crossoverMethod)
simpleGeneticAlgorthm.setMutationMethod(mutationMethod)
simpleGeneticAlgorthm.setFitnessMethod(fitness_method=fitnessMethod)
simpleGeneticAlgorthm.setReportingMethodAndFrequency(reporting_method=reportingMethod, reporting_frequency=reporting_frequency)

# %%
best_commandNodeSeries = simpleGeneticAlgorthm.evolve(num_generations=num_generations)
# Out:
# Top 5 route fitness scores
# --------------------------
# 1 : 9.670690214092815
# 2 : 10.270052232318665
# 3 : 10.423985347531906
# 4 : 11.582428575921206
# 5 : 11.76178328497622
# 6 : 12.29712633717937
# evolving generation 1 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 9.670690214092815
# 2 : 10.134347342506356
# 3 : 10.40817703553261
# 4 : 10.741097320183714
# 5 : 10.820203833900607
# 6 : 10.965209575274914
# evolving generation 2 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 8.99412044790386
# 2 : 9.517344289722152
# 3 : 9.524457268597507
# 4 : 9.670690214092815
# 5 : 10.027343894676648
# 6 : 10.286678787085606
# evolving generation 3 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 8.99412044790386
# 2 : 9.062566558520784
# 3 : 9.072195650479726
# 4 : 9.534548455580996
# 5 : 10.059785805901555
# 6 : 10.264464190498245
# evolving generation 4 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 8.99412044790386
# 2 : 9.130182737769008
# 3 : 9.46488905388808
# 4 : 10.139827457092222
# 5 : 10.15159221485204
# 6 : 10.731636520469495
# evolving generation 5 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 8.99412044790386
# 2 : 9.244171528849757
# 3 : 10.244075188923162
# 4 : 10.28958777458999
# 5 : 10.65624359400935
# 6 : 10.731636520469495
# evolving generation 6 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 8.635271405248796
# 2 : 8.710997289874477
# 3 : 8.99412044790386
# 4 : 9.06887157941323
# 5 : 10.015420212137345
# 6 : 10.785919811130952
# evolving generation 7 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 8.635271405248796
# 2 : 8.710997289874477
# 3 : 8.921111961820177
# 4 : 9.054214072061258
# 5 : 9.137065838474271
# 6 : 9.954309725425839
# evolving generation 8 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 8.635271405248796
# 2 : 8.635271405248796
# 3 : 8.921111961820177
# 4 : 9.046286003854307
# 5 : 9.065934945381832
# 6 : 10.063359494784773
# evolving generation 9 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 8.635271405248796
# 2 : 8.635271405248796
# 3 : 8.635271405248796
# 4 : 8.926831306397466
# 5 : 9.065934945381832
# 6 : 9.223561775828076
# evolving generation 10 of 10
# Final score: 8.635271405248796

# %%
best_commandNodeSeries.plotBigTrackAndRoute(coordinate_labels=True)
