# %%
#Load racetrack and route modelling dependencies
# %run ./src/Racetrack.ipynb
# %run ./src/RacetrackCommandNodeSeries.ipynb
# %run ./src/SimpleGeneticAlgorithm.ipynb

# %%
#Load genetic algorithm default method implementations
# %run ./DeepRacerRouteGAMethods.ipynb

# %%
#How many routes in the pool
pool_size = 10
#How many generations to run
num_generations = 10
#How frequently to print status report
reporting_frequency = 1
#Set the frequency of command points (init_cp_frequency) to a lower number because this track has some very tight turns
#A low init_cp_frequency will take longer to converge to an optimum route
init_cp_frequency = 20
#Verbosity 0:silent, 1:basic, 2:unbearable
verbosity = 2

# %%
#Initialize the racetrack
racetrack = Racetrack(waypointFilePath="./track-data/New_York_Eval_Track.npy")
simpleGeneticAlgorthm = SimpleGeneticAlgorthm(pool_size=pool_size, verbosity=2)

# %%
simpleGeneticAlgorthm.setInitializationMethod(initializationMethod)
simpleGeneticAlgorthm.setCrossoverMethod(crossoverMethod)
simpleGeneticAlgorthm.setMutationMethod(mutationMethod)
simpleGeneticAlgorthm.setFitnessMethod(fitness_method=fitnessMethod)
simpleGeneticAlgorthm.setReportingMethodAndFrequency(reporting_method=reportingMethod, reporting_frequency=reporting_frequency)

# %%
best_commandNodeSeries = simpleGeneticAlgorthm.evolve(num_generations=num_generations)
# Out:
# Initializing first generation pool of 10 ...
# Fixing obstruction at command node: [394, 0.7121964807143459]
# adding a new command node at inner index: 397
# Fixing obstruction at command node: [297, 0.025718117995777855]
# adding a new command node at inner index: 294
# Fixing obstruction at command node: [185, 0.5771256167696295]
# adding a new command node at inner index: 186
# Fixing obstruction at command node: [186, 0.37792131922063776]
# adding a new command node at inner index: 190
# Fixing obstruction at command node: [186, 0.29871839088682867]
# adding a new command node at inner index: 190
# Fixing obstruction at command node: [190, 0.25148195574264154]
# adding a new command node at inner index: 188
# Fixing obstruction at command node: [190, 0.32139405396043225]
# adding a new command node at inner index: 189
# Fixing obstruction at command node: [189, 0.1401445685844377]
# adding a new command node at inner index: 192
# Fixing obstruction at command node: [189, 0.3605844338513098]
# adding a new command node at inner index: 190
# Fixing obstruction at command node: [190, 0.2682949811729108]
# adding a new command node at inner index: 189
# Fixing obstruction at command node: [189, 0.4048794091275639]
# adding a new command node at inner index: 189
# Fixing obstruction at command node: [186, 0.3620096120473736]
# adding a new command node at inner index: 190
# Fixing obstruction at command node: [189, 0.43786235160471465]
# adding a new command node at inner index: 187
# Fixing obstruction at command node: [189, 0.44812461509711893]
# adding a new command node at inner index: 189
# Fixing obstruction at command node: [189, 0.39977053856645656]
# adding a new command node at inner index: 189
# Fixing obstruction at command node: [189, 0.40318762613853454]
# adding a new command node at inner index: 189
# Fixing obstruction at command node: [189, 0.27953026112027285]
# Unable to resolve route obstruction. This usually happens when there is (1) a problem with the track data or (2) The CP frequency is too low
# Terminating...
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# E:\Dev\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
best_commandNodeSeries.plotBigTrackAndRoute(coordinate_labels=True)
