# %%
#Load racetrack and route modelling dependencies
# %run ./src/Racetrack.ipynb
# %run ./src/RacetrackCommandNodeSeries.ipynb
# %run ./src/SimpleGeneticAlgorithm.ipynb

# %%
#Load genetic algorithm default method implementations
# %run ./DeepRacerRouteGAMethods.ipynb

# %%
#How many routes in the pool
pool_size = 10
#How many generations to run
num_generations = 10
#How frequently to print status report
reporting_frequency = 1

# %%
#Initialize the racetrack
racetrack = Racetrack(waypointFilePath="./track-data/Bowtie_track.npy")
simpleGeneticAlgorthm = SimpleGeneticAlgorthm(pool_size=pool_size)

# %%
simpleGeneticAlgorthm.setInitializationMethod(initializationMethod)
simpleGeneticAlgorthm.setCrossoverMethod(crossoverMethod)
simpleGeneticAlgorthm.setMutationMethod(mutationMethod)
simpleGeneticAlgorthm.setFitnessMethod(fitness_method=fitnessMethod)
simpleGeneticAlgorthm.setReportingMethodAndFrequency(reporting_method=reportingMethod, reporting_frequency=reporting_frequency)

# %%
best_commandNodeSeries = simpleGeneticAlgorthm.evolve(num_generations=num_generations)
# Out:
# Top 5 route fitness scores
# --------------------------
# 1 : 9.998569548205161
# 2 : 10.009483225543574
# 3 : 10.390870013088977
# 4 : 10.820465168478293
# 5 : 10.953893842808606
# 6 : 11.146557395681592
# evolving generation 1 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 9.858633912170669
# 2 : 9.998569548205161
# 3 : 10.178147848458673
# 4 : 10.189418395240075
# 5 : 10.477108500380922
# 6 : 10.873192793297138
# evolving generation 2 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 8.995341218572104
# 2 : 9.806566115760914
# 3 : 9.858633912170669
# 4 : 10.007332318766734
# 5 : 10.448126574017913
# 6 : 10.550152596984061
# evolving generation 3 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 8.995341218572104
# 2 : 9.180276072280579
# 3 : 9.806566115760914
# 4 : 9.886050864476134
# 5 : 10.119869229209066
# 6 : 10.274959322324102
# evolving generation 4 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 8.995341218572104
# 2 : 9.013749540476768
# 3 : 9.095152485464027
# 4 : 9.486675416247305
# 5 : 10.00947477408323
# 6 : 10.1192905771157
# evolving generation 5 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 8.920431161605643
# 2 : 8.995341218572104
# 3 : 8.997148457926924
# 4 : 9.54304476855741
# 5 : 10.00947477408323
# 6 : 10.243862453619561
# evolving generation 6 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 8.82822090419234
# 2 : 8.920431161605643
# 3 : 8.995341218572104
# 4 : 8.995341218572104
# 5 : 9.499167562681752
# 6 : 9.758665990155098
# evolving generation 7 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 8.82822090419234
# 2 : 8.888175008613045
# 3 : 9.305094068688353
# 4 : 9.596291829211424
# 5 : 9.657055093702432
# 6 : 9.667677092892074
# evolving generation 8 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 8.82822090419234
# 2 : 9.108450428746961
# 3 : 9.425555204744365
# 4 : 9.565260172873229
# 5 : 9.719425744893568
# 6 : 9.793512067396827
# evolving generation 9 of 10
# Top 5 route fitness scores
# --------------------------
# 1 : 8.769920189768335
# 2 : 8.82822090419234
# 3 : 9.672496204602067
# 4 : 9.756735309078152
# 5 : 9.80598173768115
# 6 : 9.920871659023616
# evolving generation 10 of 10
# Final score: 8.769920189768335

# %%
best_commandNodeSeries.plotBigTrackAndRoute(coordinate_labels=True)
